# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Student_data.csv')
df
# Out:
#     Hours_Studied  Previous_Test_Scores  Math_Score
# 0               9                    88          89
# 1               6                    73          77
# 2               9                    87          83
# 3               8                    83          72
# 4              10                    88          97
# ..            ...                   ...         ...
# 95              6                    67          77
# 96              4                    43          64
# 97              8                    71          69
# 98              7                    83          69
# 99              5                    82          80
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    Hours_Studied  Previous_Test_Scores  Math_Score
# 0              9                    88          89
# 1              6                    73          77
# 2              9                    87          83
# 3              8                    83          72
# 4             10                    88          97

# %%
a=df['Hours_Studied']
b=df['Math_Score']

# %%
import matplotlib.pyplot as plt
plt.scatter(a, b, color = 'green')
plt.xlabel('Hours_Studied')
plt.ylabel('Math_Score')
plt.show()

# %%
x = df[['Hours_Studied', 'Previous_Test_Scores']]
y = df['Math_Score']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state =42
                                                    )
x_train
# Out:
#     Hours_Studied  Previous_Test_Scores
# 55              5                    67
# 88              2                    58
# 26              6                    75
# 42              8                    86
# 69             10                    92
# ..            ...                   ...
# 60              5                    75
# 71              1                    41
# 14             10                    85
# 92              5                    77
# 51              2                    48
#
# [80 rows x 2 columns]

# %%
#Train model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred = regressor.predict(x_test)
print("Predicted",y_pred)
print("Test data set Y value", y_test)
# Out:
# Predicted [90.90997016 56.58365347 48.79086961 73.04702867 75.82544749 91.8084914
#  68.47156736 77.66391753 83.13790007 87.6926476  84.93494255 88.59116884
#  64.81534107 52.88599963 55.22551472 89.97002137 57.48217471 55.64370468
#  79.02205628 60.69949727]
# Test data set Y value 83    92
# 53    56
# 70    56
# 45    87
# 44    72
# 39    86
# 22    69
# 80    86
# 10    67
# 0     89
# 18    80
# 30    95
# 73    53
# 33    53
# 90    42
# 4     97
# 76    62
# 77    65
# 12    72
# 31    50
# Name: Math_Score, dtype: int64

# %%
#r square
from sklearn.metrics import r2_score
R_square = r2_score(y_test, y_pred)
print('Coefficient of Determination', R_square)
# Out:
# Coefficient of Determination 0.7500286095936588

# %%
y_train
# Out:
# 55    89
# 88    63
# 26    76
# 42    73
# 69    83
#       ..
# 60    86
# 71    56
# 14    84
# 92    87
# 51    59
# Name: Math_Score, Length: 80, dtype: int64

# %%
# Plot the scatter plot
plt.scatter(x_train['Hours_Studied'], y_train, color='green')

# Plot the regression line
regressor.fit(x_train[['Hours_Studied']], y_train)
plt.plot(x_train['Hours_Studied'], regressor.predict(x_train[['Hours_Studied']]), color='blue')

# Set the title and axis labels
plt.title('Hours_Studied vs Math_Score (Training set)')
plt.xlabel('Hours_Studied')
plt.ylabel('Math_Score')

# Display the plot
plt.show()

# %%
# Plot the scatter plot
plt.scatter(x_train['Previous_Test_Scores'], y_train, color='green')

# Plot the regression line
regressor.fit(x_train[['Previous_Test_Scores']], y_train)
plt.plot(x_train['Previous_Test_Scores'], regressor.predict(x_train[['Previous_Test_Scores']]), color='blue')

# Set the title and axis labels
plt.title('Previous_Test_Scores vs Math_Score (Training set)')
plt.xlabel('Previous_Test_Scores')
plt.ylabel('Math_Score')

# Display the plot
plt.show()
